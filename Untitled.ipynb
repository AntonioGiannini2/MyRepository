# %%
print("Ciao")
# Out:
# Ciao

# %%
x = 12
word = "Help" "a"
print(word)
# Out:
# Helpa

# %%
x=1.786
y=str(x)
z=float(y)
print(z)
# Out:
# 1.786

# %%
print("This is a \n carriage return \n")
# Out:
# This is a
#  carriage return

# %%
a=input("Inserisci un nome: ")
print(a)
# Out:
# Inserisci un nome:Antonio
# Antonio

# %%
x=input("Insert a number: ")
y=pow(float(x),2)-1
print("y=x^2-1 with x=" + str(x) + " is " + str(y))
# Out:
# Insert a number: 2
# y=x^2-1 with x=2 is 3.0

# %%
list = [1,2,3,4,5,"pippo"]
for i in list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# pippo

# %%
a=int(input("Please insert an integer number: "))
if pow(a,2) > 20:
    print(str(a) + "^2 is greater than 20")
elif pow(a,2) < 20:
    print(str(a) + "^2 is lesser than 20")
else:
    print("Something went wrong")
# Out:
# Please insert an integer number: 45
# 45^2 is greater than 20

# %%
x = 0
while x < 20:
    print("Valore non adeguato")
    x+=1
# Out:
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato
# Valore non adeguato

# %%
import pandas as pd
a = pd.read_csv("C:\\Users\\admin\\Downloads\\drive-download-20220912T105020Z-001\\ordini.csv")

# %%
a
# Out:
#         Unnamed: 0             OrderId           AccountId OrderStatus  \
# 0                0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# 1                1  8011i000001vYiXAAU  0011i00000GVD8aAAH      Closed
# 2                2  8011i000001vYiYAAU  0011i00000GVD8aAAH      Closed
# 3                3  8011i000001vYiZAAU  0011i00000GVD8aAAH      Closed
# 4                4  8011i000001vYiaAAE  0011i00000GVD8aAAH      Closed
# ...            ...                 ...                 ...         ...
# 378292      378292  8011i000009G2iIAAS  0011i00000GUvy6AAD      Closed
# 378293      378293  8011i000009G2iJAAS  0011i00000oT31qAAC      Closed
# 378294      378294  8011i000009G2liAAC  0011i00000vdH1kAAE      Closed
# 378295      378295  8011i000009G2ljAAC  0011i00000vdGvxAAE      Closed
# 378296      378296  8011i000009G2lkAAC  0011i00000QhTZ4AAN      Closed
#
#        effectivate_date store_id  totale_ordine
# 0            2019-05-20    PDV30           0.00
# ...

# %%
b = pd.read_csv("C:\\Users\\admin\\Downloads\\drive-download-20220912T105020Z-001\\order_item.csv")

# %%
b
# Out:
#          Unnamed: 0             OrderId      Order_Items_id  \
# 0                 0  8011i000001wHmEAAU  8021i000002BeisAAC
# 1                 1  8011i000001wHmEAAU  8021i000002BeitAAC
# 2                 2  8011i000001weDnAAI  8021i000002BeiuAAC
# 3                 3  8011i000001vnKOAAY  8021i000002BeivAAC
# 4                 4  8011i000001vnKOAAY  8021i000002BeiwAAC
# ...             ...                 ...                 ...
# 1651306     1651306  8017U000000L9AEQA0  8027U000000H33yQAC
# 1651307     1651307  8017U000000L9AEQA0  8027U000000H33zQAC
# 1651308     1651308  8017U000000L9AFQA0  8027U000000H340QAC
# 1651309     1651309  8017U000000L9AGQA0  8027U000000H341QAC
# 1651310     1651310  8017U000000L9AHQA0  8027U000000H342QAC
#
#                  Product_Id  Quantity  TotalPrice  Discount
# 0        01t1i000000m6JCAAY       1.0       90.30      0.30
# 1        01t1i000000m8DnAAI       1.0       63.20      0.20
# 2        01t1i000000m79SAAQ       1.0      181.30      0.30
# ...

# %%
c = a.merge(b,left_on="OrderId",right_on="OrderId")

# %%
c
# Out:
#         Unnamed: 0_x             OrderId           AccountId OrderStatus  \
# 0                  0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# 1                  0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# 2                  0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# 3                  0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# 4                  0  8011i000001vYiWAAU  0011i00000GVD8aAAH      Closed
# ...              ...                 ...                 ...         ...
# 792114        378294  8011i000009G2liAAC  0011i00000vdH1kAAE      Closed
# 792115        378295  8011i000009G2ljAAC  0011i00000vdGvxAAE      Closed
# 792116        378295  8011i000009G2ljAAC  0011i00000vdGvxAAE      Closed
# 792117        378296  8011i000009G2lkAAC  0011i00000QhTZ4AAN      Closed
# 792118        378296  8011i000009G2lkAAC  0011i00000QhTZ4AAN      Closed
#
#        effectivate_date store_id  totale_ordine  Unnamed: 0_y  \
# ...
